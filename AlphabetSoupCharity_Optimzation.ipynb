# %%
# Dependencies and data.
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,OneHotEncoder
import pandas as pd
import tensorflow as tf

df = pd.read_csv("Resources/charity_data.csv")
df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %% [markdown]
# ### Step 1 - Do Not Drop Name Column
#
# We noticed that there are multiple applications from the same companies, so we will try to bin these instead of dropping them.

# %%
# Drop EIN column.
df = df.drop(['EIN'], 1)
# Multiple same-name values, we should investigate bucketing them.

# Bucket APPLICATION_TYPE variable.
app_counts = df.APPLICATION_TYPE.value_counts()
replace_application = list(app_counts[app_counts < 500].index)
for app in replace_application:
    df.APPLICATION_TYPE = df.APPLICATION_TYPE.replace(app,"Other")

# Bucket CLASSIFICATION variable.
class_counts = df.CLASSIFICATION.value_counts()
replace_class = list(class_counts[class_counts < 1000].index)
for cls in replace_class:
    df.CLASSIFICATION = df.CLASSIFICATION.replace(cls,"Other")

# %% [markdown]
# We choose to bin any names that appear less than 10 times, and put them in an "OTHER" category.

# %%
# Bucket NAME variable.
name_counts = df.NAME.value_counts()
replace_name = list(name_counts[name_counts < 10].index)
for name in replace_name:
    df.NAME = df.NAME.replace(name, "OTHER")
# Check success at binning.
df.NAME.value_counts()
# Out:
# OTHER                                   21022
# PARENT BOOSTER USA INC                   1260
# TOPS CLUB INC                             765
# UNITED STATES BOWLING CONGRESS INC        700
# WASHINGTON STATE UNIVERSITY               492
#                                         ...
# FREE & ACCEPTED MASONS OF WASHINGTON       10
# BOYS TEAM CHARITY INC                      10
# CASCADE 4-H FOUNDATION                     10
# CALIFORNIA WOMENS CHORUS                   10
# GENERAL FEDERATION OF WOMENS CLUB          10
# Name: NAME, Length: 223, dtype: int64

# %% [markdown]
# ### Step 2 - Bin Income Amount Variable
# We turns this variable into a yes/no binary classifier, either they have income (>0) or they don't.

# %%
# Bucket INCOME_AMT variable.
inc_counts = df.INCOME_AMT.value_counts()
replace_income = list(inc_counts[inc_counts > 0].index)
for income in replace_income:
    df.INCOME_AMT = df.INCOME_AMT.replace(income, 1)
# Check success at binning.
df.INCOME_AMT.value_counts()
# Out:
# 1    34299
# Name: INCOME_AMT, dtype: int64

# %%
# Encode the categorical variables, and merge with main DF.
cats = df.dtypes[df.dtypes == 'object'].index.tolist()

enc = OneHotEncoder(sparse=False)
encode_df = pd.DataFrame(enc.fit_transform(df[cats]))
encode_df.columns = enc.get_feature_names(cats)

df = df.merge(encode_df, left_index=True, right_index=True).drop(cats, 1)

# %%
# Split target variables and dataset into training-testing.
y = df.IS_SUCCESSFUL
X = df.drop('IS_SUCCESSFUL', 1)
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Import checkpoint dependencies.
import os
from tensorflow.keras.callbacks import ModelCheckpoint

# Define the checkpoint path and filenames.
os.makedirs("checkpoints_optimized/",exist_ok=True)
checkpoint_path = "checkpoints_optimized/weights.{epoch:02d}.hdf5"

# Create the callback Checkpoint function.
cp_callback = ModelCheckpoint(
    filepath=checkpoint_path,
    verbose=1,
    save_weights_only=True,
    save_freq=4020
)
# Each epoch is 804 batches => 5*804=4020 batches to checkpoint for 5 epochs.

# %% [markdown]
# ### Step 3 - Different Layers, Neurons, and Activations
# We add a third hidden layer, and increase the number of nodes (neurons) each layer has. We make use of the tanh activation function, and increase the number of epochs from 50 to 100.

# %%
# Define model inputs.
number_input_features = len(X_train_scaled[0])
nodes_l1 = 100
nodes_l2 = 50
nodes_l3 = 20

nn = tf.keras.models.Sequential()

# Add hidden layers (3) and output layer.
nn.add(tf.keras.layers.Dense(units=nodes_l1, input_dim=number_input_features, activation='relu'))
nn.add(tf.keras.layers.Dense(units=nodes_l2, activation='relu'))
nn.add(tf.keras.layers.Dense(units=nodes_l3, activation='tanh'))
nn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

nn.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

nn.fit(X_train_scaled, y_train, epochs=100, callbacks=[cp_callback])
# Out:
# Epoch 1/100
# 804/804 [==============================] - 3s 2ms/step - loss: 0.4736 - accuracy: 0.7700
# Epoch 2/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4521 - accuracy: 0.7804
# Epoch 3/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4489 - accuracy: 0.7811
# Epoch 4/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4462 - accuracy: 0.7810
# Epoch 5/100
# 791/804 [============================>.] - ETA: 0s - loss: 0.4454 - accuracy: 0.7809
# Epoch 00005: saving model to checkpoints_optimized\weights.05.hdf5
# 804/804 [==============================] - 2s 3ms/step - loss: 0.4452 - accuracy: 0.7805
# Epoch 6/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4453 - accuracy: 0.7808
# Epoch 7/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4441 - accuracy: 0.7809
# Epoch 8/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4429 - accuracy: 0.7821
# Epoch 9/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4428 - accuracy: 0.7825
# Epoch 10/100
# 801/804 [============================>.] - ETA: 0s - loss: 0.4428 - accuracy: 0.7831
# Epoch 00010: saving model to checkpoints_optimized\weights.10.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4424 - accuracy: 0.7833
# Epoch 11/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4421 - accuracy: 0.7827
# Epoch 12/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4417 - accuracy: 0.7833
# Epoch 13/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4408 - accuracy: 0.7841
# Epoch 14/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4410 - accuracy: 0.7830
# Epoch 15/100
# 793/804 [============================>.] - ETA: 0s - loss: 0.4402 - accuracy: 0.7837
# Epoch 00015: saving model to checkpoints_optimized\weights.15.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4404 - accuracy: 0.7834
# Epoch 16/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4402 - accuracy: 0.7847
# Epoch 17/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4398 - accuracy: 0.7841
# Epoch 18/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4394 - accuracy: 0.7855
# Epoch 19/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4388 - accuracy: 0.7853
# Epoch 20/100
# 794/804 [============================>.] - ETA: 0s - loss: 0.4392 - accuracy: 0.7837
# Epoch 00020: saving model to checkpoints_optimized\weights.20.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4387 - accuracy: 0.7839
# Epoch 21/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4384 - accuracy: 0.7857
# Epoch 22/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4376 - accuracy: 0.7861
# Epoch 23/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4375 - accuracy: 0.7868
# Epoch 24/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4370 - accuracy: 0.7856
# Epoch 25/100
# 801/804 [============================>.] - ETA: 0s - loss: 0.4366 - accuracy: 0.7860
# Epoch 00025: saving model to checkpoints_optimized\weights.25.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4365 - accuracy: 0.7860
# Epoch 26/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4370 - accuracy: 0.7858
# Epoch 27/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4365 - accuracy: 0.7876
# Epoch 28/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4367 - accuracy: 0.7864
# Epoch 29/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4357 - accuracy: 0.7863
# Epoch 30/100
# 795/804 [============================>.] - ETA: 0s - loss: 0.4358 - accuracy: 0.7868
# Epoch 00030: saving model to checkpoints_optimized\weights.30.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4363 - accuracy: 0.7865
# Epoch 31/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4358 - accuracy: 0.7862
# Epoch 32/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4356 - accuracy: 0.7869
# Epoch 33/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4353 - accuracy: 0.7872
# Epoch 34/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4360 - accuracy: 0.7863
# Epoch 35/100
# 788/804 [============================>.] - ETA: 0s - loss: 0.4360 - accuracy: 0.7856
# Epoch 00035: saving model to checkpoints_optimized\weights.35.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4359 - accuracy: 0.7856
# Epoch 36/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4354 - accuracy: 0.7856
# Epoch 37/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4351 - accuracy: 0.7861
# Epoch 38/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4348 - accuracy: 0.7860
# Epoch 39/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4341 - accuracy: 0.7872
# Epoch 40/100
# 786/804 [============================>.] - ETA: 0s - loss: 0.4348 - accuracy: 0.7857
# Epoch 00040: saving model to checkpoints_optimized\weights.40.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4347 - accuracy: 0.7860
# Epoch 41/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4343 - accuracy: 0.7872
# Epoch 42/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4340 - accuracy: 0.7869
# Epoch 43/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.4345 - accuracy: 0.7866
# Epoch 44/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4339 - accuracy: 0.7873
# Epoch 45/100
# 799/804 [============================>.] - ETA: 0s - loss: 0.4356 - accuracy: 0.7863
# Epoch 00045: saving model to checkpoints_optimized\weights.45.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4353 - accuracy: 0.7866
# Epoch 46/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4344 - accuracy: 0.7875
# Epoch 47/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4336 - accuracy: 0.7880
# Epoch 48/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4334 - accuracy: 0.7872
# Epoch 49/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4335 - accuracy: 0.7876
# Epoch 50/100
# 790/804 [============================>.] - ETA: 0s - loss: 0.4334 - accuracy: 0.7880
# Epoch 00050: saving model to checkpoints_optimized\weights.50.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4336 - accuracy: 0.7878
# Epoch 51/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4342 - accuracy: 0.7876
# Epoch 52/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4340 - accuracy: 0.7874
# Epoch 53/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4331 - accuracy: 0.7889
# Epoch 54/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4337 - accuracy: 0.7886
# Epoch 55/100
# 797/804 [============================>.] - ETA: 0s - loss: 0.4341 - accuracy: 0.7885
# Epoch 00055: saving model to checkpoints_optimized\weights.55.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4341 - accuracy: 0.7885
# Epoch 56/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4322 - accuracy: 0.7876
# Epoch 57/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4319 - accuracy: 0.7883
# Epoch 58/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4331 - accuracy: 0.7884
# Epoch 59/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4334 - accuracy: 0.7896
# Epoch 60/100
# 787/804 [============================>.] - ETA: 0s - loss: 0.4334 - accuracy: 0.7886
# Epoch 00060: saving model to checkpoints_optimized\weights.60.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4332 - accuracy: 0.7889
# Epoch 61/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4325 - accuracy: 0.7891
# Epoch 62/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4325 - accuracy: 0.7886
# Epoch 63/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4328 - accuracy: 0.7883
# Epoch 64/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4332 - accuracy: 0.7881
# Epoch 65/100
# 786/804 [============================>.] - ETA: 0s - loss: 0.4313 - accuracy: 0.7894
# Epoch 00065: saving model to checkpoints_optimized\weights.65.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4322 - accuracy: 0.7891
# Epoch 66/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4330 - accuracy: 0.7891
# Epoch 67/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4326 - accuracy: 0.7889
# Epoch 68/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4319 - accuracy: 0.7887
# Epoch 69/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4322 - accuracy: 0.7870
# Epoch 70/100
# 803/804 [============================>.] - ETA: 0s - loss: 0.4327 - accuracy: 0.7889
# Epoch 00070: saving model to checkpoints_optimized\weights.70.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4329 - accuracy: 0.7888
# Epoch 71/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4321 - accuracy: 0.7885
# Epoch 72/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4317 - accuracy: 0.7889
# Epoch 73/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4323 - accuracy: 0.7882
# Epoch 74/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4327 - accuracy: 0.7896
# Epoch 75/100
# 799/804 [============================>.] - ETA: 0s - loss: 0.4324 - accuracy: 0.7903
# Epoch 00075: saving model to checkpoints_optimized\weights.75.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4322 - accuracy: 0.7904
# Epoch 76/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4323 - accuracy: 0.7879
# Epoch 77/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4325 - accuracy: 0.7886
# Epoch 78/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4322 - accuracy: 0.7884
# Epoch 79/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4322 - accuracy: 0.7894
# Epoch 80/100
# 793/804 [============================>.] - ETA: 0s - loss: 0.4317 - accuracy: 0.7883
# Epoch 00080: saving model to checkpoints_optimized\weights.80.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4320 - accuracy: 0.7878
# Epoch 81/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4315 - accuracy: 0.7888
# Epoch 82/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4321 - accuracy: 0.7898
# Epoch 83/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4330 - accuracy: 0.7902
# Epoch 84/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4324 - accuracy: 0.7889
# Epoch 85/100
# 790/804 [============================>.] - ETA: 0s - loss: 0.4317 - accuracy: 0.7893
# Epoch 00085: saving model to checkpoints_optimized\weights.85.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4320 - accuracy: 0.7890
# Epoch 86/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4330 - accuracy: 0.7894
# Epoch 87/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4323 - accuracy: 0.7894
# Epoch 88/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4317 - accuracy: 0.7884
# Epoch 89/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4321 - accuracy: 0.7895
# Epoch 90/100
# 789/804 [============================>.] - ETA: 0s - loss: 0.4321 - accuracy: 0.7888
# Epoch 00090: saving model to checkpoints_optimized\weights.90.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4320 - accuracy: 0.7886
# Epoch 91/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4318 - accuracy: 0.7900
# Epoch 92/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4323 - accuracy: 0.7901
# Epoch 93/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4317 - accuracy: 0.7906
# Epoch 94/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4317 - accuracy: 0.7888
# Epoch 95/100
# 804/804 [==============================] - ETA: 0s - loss: 0.4324 - accuracy: 0.7898
# Epoch 00095: saving model to checkpoints_optimized\weights.95.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4324 - accuracy: 0.7898
# Epoch 96/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4327 - accuracy: 0.7896
# Epoch 97/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4327 - accuracy: 0.7886
# Epoch 98/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4330 - accuracy: 0.7891
# Epoch 99/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4330 - accuracy: 0.7889
# Epoch 100/100
# 794/804 [============================>.] - ETA: 0s - loss: 0.4330 - accuracy: 0.7878
# Epoch 00100: saving model to checkpoints_optimized\weights.100.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4330 - accuracy: 0.7878

# %% [markdown]
# ### Model Outcome
# The model ends with an accuracy of 78.8%, higher than the required 75%.

# %%
# Save the whole model. - Export the model to an HDF5 model.
nn.save('AlphabetSoupCharity_Optimzation.h5')

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled, y_test, verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.4617 - accuracy: 0.7760
# Loss: 0.46167871356010437, Accuracy: 0.7759766578674316
